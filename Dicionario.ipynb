# %%
from pprint import pprint

Meu_dicionario = {"nome":"Guilherme","sobrenome":"Branquinho", "idade":16 , "peso": 76 }
pprint(Meu_dicionario)
# Out:
# {'idade': 16, 'nome': 'Guilherme', 'peso': 76, 'sobrenome': 'Branquinho'}
