# %% [markdown]
# ### Operadores Matematicos em python

# %%
# soma em python
1 + 1
# subtração em python
10 - 5
# Multiplicação 
10 * 3
# Divisão
100 / 10
# Divisão inteira
10 // 3
# Resto da divisão
11 % 2
# Potência
5 ** 2
# Raiz quadrada
81 ** 0.5 # ou 81 ** (1/2)

### Operadores Booleanos
# Out:
# 9.0

# %% [markdown]
# ### Operadores Booleanos

# %%
# Operador de igual
# obs: Um "=" é atribuição, dois "==" é comparação
5 == 3
# Operador de diferente
5 != 3
"maria" == "maria"
# Maior/igual que
5 >= 3
# Maior que
5 > 3
# Menor/igual que
5 <= 3
# Menor que
2 < 5
# Out:
# False

# %%
print()
