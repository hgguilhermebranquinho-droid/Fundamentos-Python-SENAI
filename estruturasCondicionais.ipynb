# %%
temperatura = float(input("Digite a temperatura em Graus Celsius"))
if temperatura > 28:
    print("'Poxa' Está quente!")
elif temperatura >= 15 and temperatura <= 28 :
    print("O clima está agradavel!")
else:
    if temperatura < 0:
        print("Meu Deus, Congelou meu pé!")
    else:
        print("Está frio!")



# print("Esse print acontece independente do if")
# Out:
# Meu Deus, Congelou meu pé!
# Está frio!

# %%
temperatura = float(input("Digite a temperatura em Celsius: "))
if temperatura > 30:
    print("Está quente!")
elif temperatura < 15:
    print("Está frio!")
    if temperatura < 0:
        print("Mas é frio pra cacildes!")
else:
    print("Está agradável!")
# Out:
# Está frio!
# Mas é frio pra cacildes!
